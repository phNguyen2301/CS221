# %%
import io
import numpy as np
from collections import defaultdict
from sklearn.model_selection import train_test_split
import pandas as pd
import math

# %%
gold_corpus = io.open("./Data/gold.txt", encoding="utf-8").readlines()
gold_corpus[:5]
# Out:
# ['thành_phố/N washington/N có/V 1/M kiến_trúc/N rất/R đa_dạng/A\n',
#  'tuy_nhiên/C vì/E gặp/V nhiều/A khó_khăn/N trong/E cuộc_sống/N ông/N dần/R trở_nên/V khó_tính/A\n',
#  'khí_hậu/N hồng_kông/N thuộc/V kiểu/N cận_nhiệt_đới/N và/C chịu/V ảnh_hưởng/V của/E gió_mùa/N\n',
#  'khoảng/A hơn/A 70/M bề_mặt/N trái_đất/N được/V bao_phủ/V bởi/E các/D đại_dương/N nước_mặn/N phần/N còn_lại/V là/V các/D lục_địa/N và/C các/D đảo/N\n',
#  'đà_lạt/N là/V thành_phố/N trực_thuộc/V tỉnh/N lâm_đồng/N nằm/V trên/E cao_nguyên/N lâm_viên/N thuộc/V vùng/N tây_nguyên/N việt_nam/N\n']

# %%
def format(data):
  formated = []
  for line in data:
    sentence = []
    words_tags = line.split()
    for word_tag in words_tags:
      word, tag = word_tag.split("/")
      sentence.append((word,tag))
    formated.append(sentence)
  return formated

# %%
data = format(gold_corpus)

# %%
train_set, test_set = train_test_split(data, train_size=0.8, random_state=23, shuffle=True)

# %%
print(len(train_set))
print(len(test_set))
# Out:
# 49
# 13

# %%
with open('./Vocab/vocab.txt', encoding='utf8') as f:
  vocab = f.read().splitlines() 
vocab_dict = {}
index = 0
for word in sorted(vocab): 
    if word not in vocab_dict: 
        vocab_dict[word] = index  
        index += 1

# %%
len(vocab_dict)
# Out:
# 22600

# %%
def preprocess(data, vocab_dict):
  all_tags = []
  all_words = []
  tagged_words = []
  for sent in data:
    all_tags.append("<s>")
    for word, tag in sent:
        all_tags.append(tag)
        if word not in vocab_dict:
          word = "<unk>"
        all_words.append(word)
        tagged_words.append((word, tag))
  return all_tags, all_words, tagged_words

# %%
train_tags, train_words, train_tagged_words = preprocess(train_set, vocab_dict)
test_tags, test_words, test_tagged_words = preprocess(test_set, vocab_dict)

# %%
train_words[:5]
# Out:
# ['những', 'website', 'được', 'thiết_kế', 'đẹp_mắt']

# %%
train_tags[:5]
# Out:
# ['<s>', 'D', 'N', 'V', 'V']

# %%
train_tagged_words[:5]
# Out:
# [('những', 'D'),
#  ('website', 'N'),
#  ('được', 'V'),
#  ('thiết_kế', 'V'),
#  ('đẹp_mắt', 'A')]

# %%
# transition count
def transition_count(all_tags):
  transition_count = defaultdict(int)
  prev_tag = all_tags[0]
  for i in range(1, len(all_tags)):
    tag = all_tags[i]
    transition_count[(prev_tag, tag)] += 1
    prev_tag = tag
  return transition_count
transition = transition_count(train_tags)

# %%
transition
# Out:
# defaultdict(int,
#             {('<s>', 'D'): 4,
#              ('D', 'N'): 18,
#              ('N', 'V'): 42,
#              ('V', 'V'): 27,
#              ('V', 'A'): 17,
#              ('A', 'C'): 4,
#              ('C', 'N'): 5,
#              ('N', 'A'): 15,
#              ('A', 'R'): 3,
#              ('R', 'V'): 24,
#              ('V', 'R'): 8,
#              ('R', 'N'): 2,
#              ('N', 'E'): 30,
#              ('E', 'N'): 32,
#              ('N', '<s>'): 25,
#              ('<s>', 'N'): 22,
#              ('V', 'N'): 44,
#              ('N', 'R'): 12,
#              ('E', 'P'): 8,
#              ('P', 'R'): 12,
#              ('R', 'A'): 10,
#              ('C', 'P'): 2,
#              ('P', 'V'): 18,
#              ('A', 'A'): 3,
#              ('A', '<s>'): 13,
#              ('V', 'P'): 6,
#              ('A', 'V'): 10,
#              ('V', 'D'): 6,
#              ('R', 'R'): 5,
#              ('C', 'I'): 1,
#              ('I', 'P'): 1,
#              ('A', 'E'): 5,
#              ('P', '<s>'): 3,
#              ('V', 'C'): 3,
#              ('C', 'V'): 5,
#              ('A', 'N'): 7,
#              ('N', 'P'): 9,
#              ('V', 'E'): 15,
#              ('E', 'V'): 9,
#              ('<s>', 'P'): 10,
#              ('N', 'N'): 45,
#              ('<s>', 'A'): 1,
#              ('A', 'M'): 2,
#              ('M', 'N'): 11,
#              ('E', 'D'): 5,
#              ('N', 'C'): 5,
#              ('C', 'D'): 1,
#              ('<s>', 'M'): 2,
#              ('E', 'A'): 2,
#              ('P', 'C'): 1,
#              ('<s>', 'R'): 3,
#              ('V', '<s>'): 7,
#              ('A', 'D'): 1,
#              ('R', 'E'): 1,
#              ('P', 'E'): 1,
#              ('P', 'A'): 3,
#              ('N', 'M'): 2,
#              ('<s>', 'C'): 2,
#              ('C', 'E'): 1,
#              ('<s>', 'E'): 3,
#              ('V', 'M'): 4,
#              ('R', 'M'): 1,
#              ('<s>', 'V'): 2,
#              ('M', 'E'): 1,
#              ('A', 'P'): 3,
#              ('P', 'N'): 1,
#              ('E', 'M'): 1,
#              ('N', 'D'): 1,
#              ('V', 'I'): 1,
#              ('I', 'V'): 1})

# %%
# emission count
def emission_count(tagged_words):
  emission_count = defaultdict(int)
  for tagged_word in tagged_words:
    word, tag = tagged_word
    emission_count[(tag, word)] += 1
  return emission_count
emission = emission_count(train_tagged_words)

# %%
emission
# Out:
# defaultdict(int,
#             {('D', 'những'): 10,
#              ('N', 'website'): 1,
#              ('V', 'được'): 6,
#              ('V', 'thiết_kế'): 1,
#              ('A', 'đẹp_mắt'): 1,
#              ('C', 'với'): 1,
#              ('N', 'bố_cục'): 1,
#              ('A', 'hài_hoà'): 1,
#              ('C', 'và'): 7,
#              ('N', 'tỉ_lệ'): 1,
#              ('A', 'cân_đối'): 1,
#              ('R', 'sẽ'): 3,
#              ('V', 'chiếm'): 1,
#              ('R', 'được'): 1,
#              ('N', 'thiện_cảm'): 1,
#              ('E', 'của'): 14,
#              ('N', 'người_dùng'): 2,
#              ('N', 'việc'): 2,
#              ('V', 'tối_ưu'): 1,
#              ('N', 'tốc_độ'): 1,
#              ('V', 'tải'): 1,
#              ('N', 'trang'): 1,
#              ('R', 'luôn'): 1,
#              ('V', 'là'): 12,
#              ('N', 'nhiệm_vụ'): 1,
#              ('V', 'đặt'): 2,
#              ('V', 'lên'): 1,
#              ('N', 'hàng_đầu'): 1,
#              ('N', 'tiếng_anh'): 1,
#              ('P', 'tôi'): 13,
#              ('R', 'rất'): 5,
#              ('A', 'kém'): 1,
#              ('C', 'vì_vậy'): 1,
#              ('V', 'cần'): 2,
#              ('V', 'cải_thiện'): 2,
#              ('A', 'nhiều'): 4,
#              ('A', 'hơn'): 4,
#              ('N', 'cà_phê'): 1,
#              ('E', 'ở'): 5,
#              ('P', 'đây'): 3,
#              ('V', 'làm'): 4,
#              ('V', 'phê'): 1,
#              ('V', 'tận'): 1,
#              ('N', 'nóc'): 1,
#              ('N', 'con_người'): 2,
#              ('R', 'chỉ'): 2,
#              ('A', 'đơn_giản'): 1,
#              ('N', 'cỗ_máy'): 1,
#              ('R', 'vô_cùng'): 1,
#              ('A', 'phức_tạp'): 1,
#              ('N', 'công_việc'): 2,
#              ('R', 'không'): 5,
#              ('R', 'hẳn'): 1,
#              ('A', 'dễ'): 1,
#              ('C', 'nhưng'): 2,
#              ('I', 'dường_như'): 1,
#              ('R', 'đang'): 4,
#              ('V', 'suy_nghĩ'): 1,
#              ('E', 'về'): 2,
#              ('P', 'nó'): 3,
#              ('R', 'có_thể'): 3,
#              ('V', 'xem'): 1,
#              ('V', 'chỉ'): 1,
#              ('A', 'rõ'): 1,
#              ('N', 'thông_tin'): 1,
#              ('P', 'nào'): 2,
#              ('V', 'thu_thập'): 1,
#              ('E', 'để'): 7,
#              ('V', 'thực_thi'): 1,
#              ('D', '<unk>'): 1,
#              ('N', 'chế_định'): 1,
#              ('N', 'quyền'): 1,
#              ('A', 'riêng_tư'): 1,
#              ('N', 'bài_tập'): 1,
#              ('V', 'gán'): 1,
#              ('N', 'nhãn'): 1,
#              ('N', 'từ_loại'): 1,
#              ('E', 'trong'): 6,
#              ('N', 'từ_điển'): 1,
#              ('A', 'khoảng'): 1,
#              ('M', '<unk>'): 1,
#              ('N', 'bề_mặt'): 1,
#              ('N', 'trái_đất'): 1,
#              ('V', 'bao_phủ'): 1,
#              ('E', 'bởi'): 1,
#              ('D', 'các'): 6,
#              ('N', 'đại_dương'): 1,
#              ('N', 'nước_mặn'): 1,
#              ('N', 'phần'): 1,
#              ('V', 'còn_lại'): 1,
#              ('N', 'lục_địa'): 1,
#              ('N', 'đảo'): 1,
#              ('M', '1'): 8,
#              ('N', 'nghề'): 2,
#              ('E', 'cho'): 4,
#              ('A', 'chín'): 1,
#              ('R', 'còn'): 2,
#              ('M', 'chín'): 1,
#              ('N', 'buồng_lái'): 1,
#              ('V', 'nhô'): 1,
#              ('A', 'cao'): 1,
#              ('V', 'cho_phép'): 1,
#              ('N', 'máy_bay'): 1,
#              ('V', 'chất'): 1,
#              ('V', 'dỡ'): 1,
#              ('N', 'hàng_hoá'): 2,
#              ('E', 'từ'): 2,
#              ('N', 'phía_trước'): 1,
#              ('N', 'phiên_bản'): 1,
#              ('A', 'chuyên'): 1,
#              ('V', 'chở'): 1,
#              ('P', 'bạn'): 2,
#              ('C', 'nên'): 1,
#              ('V', 'dành'): 1,
#              ('N', 'thời_gian'): 1,
#              ('V', 'cố_gắng'): 3,
#              ('V', 'phát_triển'): 1,
#              ('N', 'kiến_thức'): 2,
#              ('E', 'theo'): 1,
#              ('N', 'dạng'): 1,
#              ('N', 'hình'): 1,
#              ('N', 'chữ'): 1,
#              ('N', 't'): 1,
#              ('V', 'chịu'): 2,
#              ('R', 'nổi'): 1,
#              ('N', 'cảnh'): 1,
#              ('A', 'ồn_ào'): 1,
#              ('N', 'tiếng'): 1,
#              ('N', 'karaoke'): 1,
#              ('N', 'nơi'): 1,
#              ('N', 'công_cộng'): 1,
#              ('N', 'nhóm'): 2,
#              ('N', 'thanh_niên'): 1,
#              ('E', 'tại'): 4,
#              ('N', 'chung_cư'): 1,
#              ('N', 'linh_đàm'): 1,
#              ('V', 'đã'): 1,
#              ('V', 'mở'): 2,
#              ('N', 'nhạc'): 2,
#              ('N', 'đám_ma'): 1,
#              ('V', 'át_chế'): 1,
#              ('N', 'quả_bóng_vàng'): 1,
#              ('V', 'trao'): 1,
#              ('N', 'benzema'): 1,
#              ('N', 'cơn_gió'): 1,
#              ('A', 'căng_tràng'): 1,
#              ('V', 'vi_vu'): 1,
#              ('A', 'khắp'): 1,
#              ('N', 'núi_rừng'): 1,
#              ('N', 'đà_lạt'): 1,
#              ('V', 'khiến'): 1,
#              ('N', 'quả'): 1,
#              ('N', 'hồng'): 1,
#              ('V', 'uống'): 1,
#              ('A', 'no_nê'): 1,
#              ('N', 'giọt_sương'): 1,
#              ('A', 'mờ'): 1,
#              ('P', 'họ'): 3,
#              ('R', 'đều'): 1,
#              ('V', 'đồng_loạt'): 1,
#              ('V', 'cho_rằng'): 2,
#              ('N', 'sự_kiện'): 2,
#              ('A', 'đáng'): 1,
#              ('V', 'chú_ý'): 1,
#              ('R', 'nhất'): 1,
#              ('N', 'bóng_đá'): 1,
#              ('N', 'đông_nam_á'): 1,
#              ('P', 'tự'): 1,
#              ('P', 'mình'): 2,
#              ('E', 'vào'): 5,
#              ('N', 'vị_trí'): 1,
#              ('N', 'người'): 2,
#              ('V', 'dùng'): 1,
#              ('V', 'trải_nghiệm'): 1,
#              ('E', 'trên'): 1,
#              ('N', 'thiết_bị'): 1,
#              ('V', 'di_động'): 1,
#              ('A', 'thường_xuyên'): 2,
#              ('V', 'thức'): 1,
#              ('V', 'dậy'): 1,
#              ('N', 'lúc'): 2,
#              ('M', '6'): 1,
#              ('N', 'giờ'): 1,
#              ('N', 'sự'): 2,
#              ('V', 'kết_hợp'): 1,
#              ('V', 'tìm_kiếm'): 2,
#              ('V', 'chia_sẻ'): 1,
#              ('V', 'mang'): 1,
#              ('V', 'lại'): 1,
#              ('N', 'hiệu_ứng'): 1,
#              ('V', 'lan_truyền'): 1,
#              ('A', 'lớn'): 1,
#              ('N', 'trái_tim'): 1,
#              ('P', 'anh'): 1,
#              ('R', 'đã'): 2,
#              ('N', 'cửa'): 1,
#              ('V', 'chào_đón'): 1,
#              ('P', 'em'): 1,
#              ('C', 'tuy_nhiên'): 1,
#              ('E', 'vì'): 3,
#              ('V', 'gặp'): 2,
#              ('N', 'khó_khăn'): 1,
#              ('N', 'cuộc_sống'): 1,
#              ('N', 'ông'): 2,
#              ('R', 'dần'): 1,
#              ('V', 'trở_nên'): 2,
#              ('A', 'khó_tính'): 1,
#              ('N', 'con_sâu'): 1,
#              ('V', 'ẩn_mình'): 1,
#              ('A', 'sâu'): 1,
#              ('N', 'vòm'): 1,
#              ('N', 'cây'): 1,
#              ('E', 'khi'): 1,
#              ('A', 'ngẫu_nhiên'): 1,
#              ('N', 'từ_khóa'): 1,
#              ('V', 'có'): 5,
#              ('R', 'hàng'): 1,
#              ('M', 'ngàn'): 1,
#              ('N', 'kết_quả'): 1,
#              ('V', 'hiện'): 1,
#              ('V', 'ra'): 1,
#              ('R', 'vừa'): 3,
#              ('V', 'ngồi'): 1,
#              ('N', 'bàn'): 1,
#              ('P', 'chúng_tôi'): 1,
#              ('R', 'liền'): 1,
#              ('V', 'bắt_đầu'): 1,
#              ('V', 'bàn'): 1,
#              ('V', 'nghe'): 1,
#              ('V', 'làm_việc'): 2,
#              ('A', 'đặc_biệt'): 1,
#              ('N', 'bài_nhạc'): 1,
#              ('N', 'tiết_tấu'): 1,
#              ('A', 'nhanh'): 1,
#              ('V', 'giúp'): 1,
#              ('V', 'tránh'): 1,
#              ('V', 'khỏi'): 1,
#              ('A', 'buồn_ngủ'): 1,
#              ('N', 'điều'): 1,
#              ('V', 'phải'): 2,
#              ('V', 'bàn_cãi'): 1,
#              ('V', 'tiếp_thu'): 1,
#              ('N', 'môn_học'): 1,
#              ('V', 'xử_lí'): 1,
#              ('N', 'ngôn_ngữ'): 1,
#              ('N', 'tự_nhiên'): 1,
#              ('N', 'tư_duy'): 1,
#              ('V', 'giải_quyết'): 1,
#              ('N', 'vấn_đề'): 1,
#              ('A', 'tốt'): 1,
#              ('N', 'thành_phố'): 1,
#              ('N', 'washington'): 1,
#              ('N', 'kiến_trúc'): 1,
#              ('A', 'đa_dạng'): 1,
#              ('V', 'đổi'): 1,
#              ('N', 'đất_đai'): 1,
#              ('V', 'lấy'): 1,
#              ('N', 'hạ_tầng'): 1,
#              ('N', 'bối_cảnh'): 1,
#              ('N', 'hiện_nay'): 1,
#              ('N', 'đám_cưới'): 1,
#              ('N', 'cặp_đôi'): 1,
#              ('V', 'tổ_chức'): 1,
#              ('A', 'ấm_cúng'): 1,
#              ('N', 'nhà_riêng'): 1,
#              ('N', 'hà_nội'): 1,
#              ('N', 'chiều'): 1,
#              ('P', 'nay'): 2,
#              ('N', 'thế_vận_hội'): 1,
#              ('N', 'mùa'): 1,
#              ('N', 'hè'): 1,
#              ('A', 'đầu_tiên'): 1,
#              ('P', 'này'): 2,
#              ('N', 'nữ'): 1,
#              ('N', 'vận_động_viên'): 1,
#              ('V', 'tham_dự'): 1,
#              ('N', 'khí_hậu'): 2,
#              ('N', 'hồng_kông'): 1,
#              ('V', 'thuộc'): 1,
#              ('N', 'kiểu'): 1,
#              ('N', 'cận_nhiệt_đới'): 1,
#              ('V', 'ảnh_hưởng'): 1,
#              ('N', 'gió_mùa'): 1,
#              ('V', 'lái'): 1,
#              ('N', 'xe'): 1,
#              ('P', 'anh_ta'): 1,
#              ('V', 'nói'): 1,
#              ('N', 'lái'): 1,
#              ('N', 'kiến'): 1,
#              ('V', 'bò'): 1,
#              ('V', 'lúc_nhúc'): 1,
#              ('N', 'xung_quanh'): 1,
#              ('N', 'đĩa'): 1,
#              ('N', 'thịt'): 1,
#              ('N', 'bò'): 1,
#              ('N', 'cuối'): 1,
#              ('N', 'tuần'): 2,
#              ('N', 'trước'): 1,
#              ('V', 'về'): 1,
#              ('N', 'quê'): 1,
#              ('N', 'gia_đình'): 1,
#              ('N', 'đám'): 1,
#              ('N', 'nhân_viên'): 1,
#              ('A', 'xa'): 1,
#              ('P', 'từ'): 1,
#              ('N', 'hà_lan'): 1,
#              ('N', 'công_ty'): 1,
#              ('N', 'phần_mềm'): 1,
#              ('N', 'mỹ'): 1,
#              ('N', 'ý_nghĩa'): 1,
#              ('V', 'tiết_kiệm'): 2,
#              ('N', 'tiền'): 1,
#              ('C', 'mà'): 1,
#              ('N', 'khi'): 1,
#              ('N', 'biến_cố'): 1,
#              ('R', 'cũng'): 1,
#              ('A', 'bình_tĩnh'): 1,
#              ('N', 'trận_đấu'): 1,
#              ('N', 'tối'): 1,
#              ('V', 'diễn_ra'): 1,
#              ('N', 'sân'): 1,
#              ('N', 'thể_dục'): 1,
#              ('N', 'thể_thao'): 1,
#              ('N', 'chuyên_gia'): 1,
#              ('N', 'công_trình'): 1,
#              ('A', 'xanh'): 1,
#              ('V', 'cho'): 1,
#              ('N', 'chủ'): 1,
#              ('V', 'đầu_tư'): 1,
#              ('N', 'sau'): 1,
#              ('V', 'đưa'): 1,
#              ('D', 'mỗi'): 1,
#              ('N', 'bản'): 1,
#              ('V', 'phân_tích'): 1,
#              ('V', 'yêu_cầu'): 1,
#              ('V', 'đánh_giá'): 1,
#              ('N', 'mức_độ'): 1,
#              ('A', 'chính_xác'): 1,
#              ('P', 'đó'): 1,
#              ('N', 'thói_quen'): 1,
#              ('V', 'trồng'): 1,
#              ('N', 'hoa'): 1,
#              ('V', 'đón'): 1,
#              ('N', 'khách'): 1,
#              ('V', 'sống_ảo'): 1,
#              ('N', 'dịp'): 1,
#              ('N', 'tết'): 1,
#              ('N', 'phận'): 1,
#              ('N', 'con'): 1,
#              ('R', 'không_thể'): 1,
#              ('V', 'phụ'): 1,
#              ('N', 'công'): 1,
#              ('N', 'phụ_mẫu'): 1,
#              ('V', 'dưỡng_dục'): 1,
#              ('V', 'thực_hiện'): 1,
#              ('R', 'vẫn'): 1,
#              ('R', 'chưa'): 1,
#              ('A', 'phù_hợp'): 1,
#              ('N', 'biến_đổi'): 1,
#              ('V', 'đe_doạ'): 1,
#              ('E', 'đến'): 1,
#              ('C', 'khi'): 1,
#              ('V', 'gây'): 1,
#              ('A', 'bất_an'): 1,
#              ('N', 'lương_thực'): 1,
#              ('A', 'khan_hiếm'): 1,
#              ('N', 'nước'): 1,
#              ('N', 'lũ_lụt'): 1,
#              ('N', 'nắng_nóng'): 1,
#              ('A', 'cực_đoan'): 1,
#              ('V', 'thiệt_hại'): 1,
#              ('N', 'kinh_tế'): 1,
#              ('N', 'di_cư'): 1,
#              ('N', 'bạn'): 1,
#              ('A', 'cùng'): 1,
#              ('V', 'học'): 1,
#              ('A', 'giỏi'): 1,
#              ('N', 'thiên_tài'): 1,
#              ('N', 'internet'): 1,
#              ('N', 'ký_túc_xá'): 1,
#              ('N', 'khu'): 1,
#              ('N', 'b'): 1,
#              ('A', 'yếu'): 1,
#              ('N', 'số_lượng'): 1,
#              ('V', 'share'): 1,
#              ('I', 'chính'): 1,
#              ('N', 'đích_đến'): 1,
#              ('N', 'tất_cả'): 1,
#              ('N', 'thương_hiệu'): 1})

# %%
# tag count
def tag_count(all_tags):
  tag_count = defaultdict(int)
  for tag in all_tags:
    tag_count[tag] += 1
  return tag_count
tags = tag_count(train_tags)

# %%
tags
# Out:
# defaultdict(int,
#             {'<s>': 49,
#              'D': 18,
#              'N': 187,
#              'V': 138,
#              'A': 51,
#              'C': 15,
#              'R': 43,
#              'E': 57,
#              'P': 39,
#              'I': 2,
#              'M': 12})

# %% [markdown]
# ## only emission

# %%
states = sorted(tags.keys())

# %%
states
# Out:
# ['<s>', 'A', 'C', 'D', 'E', 'I', 'M', 'N', 'P', 'R', 'V']

# %%
# predict with emission count
def predict_pos(tagged_words, emission, vocab, states):
  num_correct = 0
  valid_states = states.copy()
  valid_states.remove("<s>")
  for tagged_word in tagged_words:
    word, true_tag = tagged_word
    count_final = 0 
    count = 0
    tag_final = ''

    for tag in valid_states:
      if word not in vocab_dict:
        tag_final = valid_states[0]
        break
      if (tag, word) not in emission:
        continue
      count = emission[(tag, word)]

      if count > count_final:
        count_final = count
        tag_final = tag
    if tag_final == true_tag:
      num_correct += 1
  accuracy = num_correct / len(tagged_words)
  return accuracy

# %%
accuracy = predict_pos(train_tagged_words, emission, vocab_dict, states)
print('Độ chính xác trên tập train:', accuracy)
# Out:
# Độ chính xác trên tập train: 0.9750889679715302

# %%
accuracy = predict_pos(test_tagged_words, emission, vocab_dict, states)
print('Độ chính xác trên tập test:', accuracy)
# Out:
# Độ chính xác trên tập test: 0.45977011494252873

# %% [markdown]
# ## hidden markov

# %%
def transition_matrix(alpha, transition, states, tags):
  len_tags = len(states)
  A = np.zeros((len_tags, len_tags))
  
  for i in range(len_tags):
    for j in range(len_tags):
      count = 0
      if (states[i], states[j]) in transition:
        count = transition[(states[i], states[j])]
      
      count_prev_tag = tags[states[i]]
      A[i, j] = (count + alpha) / (count_prev_tag + alpha * len_tags)
  return A

# %%
alpha = 0.01
A = transition_matrix(alpha, transition, states, tags)

# %%
def emission_matrix(alpha, emission, vocab_dict, states, tags):
  vocab = [v for v in vocab_dict]
  valid_states = states.copy()
  valid_states.remove("<s>")
  len_tags = len(valid_states)
  len_vocab = len(vocab)

  B = np.zeros((len_tags, len_vocab))
  
  for i in range(len_tags):
    for j in range(len_vocab):
      count = 0
      if (valid_states[i], vocab[j]) in emission:
        count = emission[(valid_states[i], vocab[j])]
      
      count_tag = tags[valid_states[i]]
      B[i,j] = (count + alpha) / (count_tag + alpha * len_vocab)
  return B

# %%
B = emission_matrix(alpha, emission,vocab_dict, states, tags)

# %%
A = np.array([sublist[1:].tolist() for sublist in A])

# %%
pd.DataFrame(A,
index = states,
columns = states[1:])
# Out:
#             A         C         D         E         I         M         N  \
# <s>  0.020566  0.040929  0.081653  0.061291  0.000204  0.040929  0.448178
# A    0.058893  0.078458  0.019761  0.098024  0.000196  0.039327  0.137155
# C    0.000662  0.000662  0.066843  0.066843  0.066843  0.000662  0.331568
# D    0.000552  0.000552  0.000552  0.000552  0.000552  0.000552  0.994478
# E    0.035195  0.000175  0.087725  0.000175  0.000175  0.017685  0.560497
# I    0.004739  0.004739  0.004739  0.004739  0.004739  0.004739  0.004739
# M    0.000826  0.000826  0.000826  0.083402  0.000826  0.000826  0.909166
# N    0.080220  0.026776  0.005398  0.160387  0.000053  0.010742  0.240554
# P    0.076962  0.025825  0.000256  0.025825  0.000256  0.000256  0.025825
# R    0.232197  0.000232  0.000232  0.023428  0.000232  0.023428  0.046625
# V    0.123163  0.021794  0.043516  0.108681  0.007313  0.029035  0.318659
#
#             P         R         V
# <s>  0.203828  0.061291  0.040929
# A    0.058893  0.058893  0.195852
# C    0.133024  0.000662  0.331568
# D    0.000552  0.000552  0.000552
# E    0.140256  0.000175  0.157766
# I    0.478673  0.004739  0.478673
# M    0.000826  0.000826  0.000826
# N    0.048153  0.064187  0.224520
# P    0.000256  0.307083  0.460496
# R    0.000232  0.116214  0.556947
# V    0.043516  0.057997  0.195569

# %%
def viterbi_initialize(states, tags, A, B, corpus, vocab_dict):
  valid_states = states.copy()
  valid_states.remove("<s>")
  len_tags = len(valid_states)

  best_probs = np.zeros((len_tags, len(corpus)))
  best_paths = np.zeros((len_tags, len(corpus)), dtype=int)

  for i in range(len_tags):
      index = vocab_dict[corpus[0]]
      best_probs[i,0] = math.log(A[0, i]) + math.log(B[i, index])
  return best_probs, best_paths

# %%
best_probs_train, best_paths_train = viterbi_initialize(states, train_tags, A, B, train_words, vocab_dict)
best_probs_test, best_paths_test = viterbi_initialize(states, tags, A, B, test_words, vocab_dict)

# %%
def viterbi_forward(A, B, corpus, best_probs, best_paths, vocabs_dict):
    num_tags = best_probs.shape[0]
    for i in range(1, len(corpus)): 
        for j in range(num_tags):
            best_prob_i = float('-inf')
            best_path_i = None
            for k in range(num_tags):
                index = vocabs_dict[corpus[i]]
                prob = best_probs[k, i - 1] + math.log(A[k, j]) + math.log(B[j, index])
                # prob = best_probs[k, i - 1] + math.log(A[k, j - 1]) + math.log(B[j - 1, index])

                if prob > best_prob_i:
                    best_prob_i = prob
                    best_path_i = k
                    
            best_probs[j, i] = best_prob_i
            best_paths[j, i] = best_path_i
            
    return best_probs, best_paths

# %%
best_probs_train, best_paths_train = viterbi_forward(A, B, train_words, best_probs_train, best_paths_train, vocab_dict)
best_probs_test, best_paths_test = viterbi_forward(A, B, test_words, best_probs_test, best_paths_test, vocab_dict)

# %%
def viterbi_backward(best_probs, best_paths, corpus, states):
    valid_states = states.copy()
    valid_states.remove("<s>")
    m = best_paths.shape[1] 
    z = [None] * m
    pred = [None] * m
    
    best_prob_for_last_word = float('-inf')
    num_tags = best_probs.shape[0]
    
    for k in range(num_tags):
        if best_probs[k, m - 1] > best_prob_for_last_word:
            best_prob_for_last_word = best_probs[k, m - 1]
            z[m - 1] = k
            
    pred[m - 1] = valid_states[z[m - 1]]
    for i in range(m - 1, -1, -1):
        z[i - 1] = best_paths[z[i], i]
        pred[i - 1] = valid_states[z[i - 1]]
    return pred

# %%
train_pred = viterbi_backward(best_probs_train, best_paths_train, train_words, states)
test_pred = viterbi_backward(best_probs_test, best_paths_test, test_words, states)

# %%
i = 0
for tag in test_tags:
  if tag == "<s>":
    print()
    continue
  else:
    print(test_words[i], end="/")
    print(test_pred[i], end=" ")
    i+=1
# Out:
# đà_lạt/N là/N thành_phố/N trực_thuộc/N tỉnh/N lâm_đồng/N nằm/N trên/E cao_nguyên/N <unk>/M thuộc/V vùng/V tây_nguyên/V việt_nam/V
# song_song/V là/V 2/A cửa_sổ/N 2/N người/N ngồi/N trong/E cửa_sổ/N song_song/N
# nó/P có/V đầy_đủ/A các/D nhân_vật/V được/V phát_triển/V chuẩn/A và/C 1/M bối_cảnh/V trò_chơi/V vô_cùng/R sống_động/R
# nhưng/C đó/P là/V chuyện/V đã/V qua/V
# nếu_như/V là/V trước_đây/V chắc/A tôi/P sẽ/R sợ/R không/R muốn/V ai/A nhìn/N thấy/N phần/N cơ_thể/N đó/N
# sau/N trận/N mưa_lũ/N lịch_sử/N đà_nẵng/N giá/N rau/N nhích/N lên/V chính_quyền/V cảnh_báo/V không/R lợi_dụng/V nâng/V giá/V
# gõ/A <unk>/D bằng/V 5/V <unk>/V sẽ/R giúp/V bạn/V có/V tốc_độ/V gõ/V nhanh/A hơn/A
# mỗi/D buổi/V chiều/A tôi/P thường/V dành/V thời_gian/N để/E tập/N gym/N hoặc/N đá/N bóng/N và/C tôi/P đang/R cố_gắng/V để/E duy_trì/N nó/N
# sứ_mệnh/N của/E <unk>/M là/V mang/V đến/A những/D trải_nghiệm/V thú_vị/A và/C độc_đáo/P cho/E người_dùng/N
# điều/N quan_trọng/N là/V bạn/V phải/V có/V mục_tiêu/V rõ_ràng/A và/C cụ_thể/P cho/E tương_lai/N của/E mình/P
# tôi/P thích/V đi/V du_lịch/V bằng/V xe_máy/V bởi/V như_vậy/V có_thể/R tận_hưởng/V <unk>/M tốt/V hơn/A
# chuối/P có/V chứa/V rất/R nhiều/A chất/V dinh_dưỡng/V cần_thiết/V cho/V cơ_thể/V
# nếu/V để_ý/A bạn/P sẽ/R thấy/V chuyện/V đôi_lứa/V bên/V nhau/V cũng/R chẳng/V khác/V 1/M cuộc/V khiêu_vũ/V là/V mấy/A

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.metrics import classification_report
def report(pred, gold):
    y_pred = pred
    y_true = [t for t in gold if t != "<s>"]
    
    print(classification_report(y_pred, y_true))
    return y_pred, y_true

# %%
print('Kết quả của HMM + Viterbi trên tập train:\n')
y_pred, y_true_train = report(train_pred, train_tags)
# Out:
# Kết quả của HMM + Viterbi trên tập train:
#
#               precision    recall  f1-score   support
#
#            A       0.94      0.83      0.88        58
#            C       0.67      0.91      0.77        11
#            D       0.50      0.90      0.64        10
#            E       0.86      0.94      0.90        52
#            I       0.00      0.00      0.00         0
#            M       0.42      0.71      0.53         7
#            N       0.82      0.72      0.77       213
#            P       0.77      0.91      0.83        33
#            R       0.86      0.97      0.91        38
#            V       0.70      0.69      0.70       140
#
#     accuracy                           0.78       562
#    macro avg       0.65      0.76      0.69       562
# weighted avg       0.79      0.78      0.78       562

# %%
print('Kết quả của HMM + Viterbi trên tập test:\n')
y_pred, y_true_test = report(test_pred, test_tags)
# Out:
# Kết quả của HMM + Viterbi trên tập test:
#
#               precision    recall  f1-score   support
#
#            A       0.47      0.50      0.48        16
#            C       0.56      1.00      0.71         5
#            D       1.00      0.75      0.86         4
#            E       0.67      1.00      0.80         8
#            M       0.40      0.40      0.40         5
#            N       0.43      0.57      0.49        40
#            P       0.62      0.73      0.67        11
#            R       0.77      0.83      0.80        12
#            V       0.67      0.44      0.53        73
#            X       0.00      0.00      0.00         0
#
#     accuracy                           0.57       174
#    macro avg       0.56      0.62      0.57       174
# weighted avg       0.60      0.57      0.57       174

# %% [markdown]
# # VNCoreNLP

# %%
import py_vncorenlp
model = py_vncorenlp.VnCoreNLP(annotators=["pos"], save_dir='./')

# %%
def predict(test_set, ifprint=True):
  pred = []
  true = []
  for sent in test_set:
    for w, t in sent:
      true.append(t)
      if "_" in w:
        w = w.replace("_", " ")
      model_pred = model.annotate_text(w)[0]
      for token in model_pred:
        if type(token) != str:
          word = token['wordForm']
          tag = token['posTag']
          if ifprint:
            print(word + '/' + tag, end=" ")
      if tag == "L":
        tag = "D"
      if tag == "T":
        tag = "X"
      pred.append(tag[0])
    if ifprint:
      print()
  return pred, true

# %%
vncore_pred, true = predict(train_set, ifprint=False)
print('Kết quả của VnCoreNLP trên tập train:\n')
y_pred, y_true_test = report(vncore_pred, true)
# Out:
# Kết quả của VnCoreNLP trên tập train:
#
#               precision    recall  f1-score   support
#
#            A       0.86      0.79      0.82        56
#            C       0.87      0.76      0.81        17
#            D       0.94      1.00      0.97        17
#            E       0.95      0.90      0.92        60
#            I       0.00      0.00      0.00         0
#            M       0.92      0.92      0.92        12
#            N       0.88      0.92      0.90       179
#            P       0.87      0.94      0.91        36
#            R       0.84      0.90      0.87        40
#            V       0.86      0.83      0.85       143
#            X       0.00      0.00      0.00         2
#
#     accuracy                           0.88       562
#    macro avg       0.73      0.72      0.72       562
# weighted avg       0.88      0.88      0.87       562

# %%
vncore_pred, true = predict(test_set, ifprint=False)
print('Kết quả của VnCoreNLP trên tập test:\n')
y_pred, y_true_test = report(vncore_pred, true)
# Out:
# Kết quả của VnCoreNLP trên tập test:
#
#               precision    recall  f1-score   support
#
#            A       0.94      1.00      0.97        16
#            C       0.89      1.00      0.94         8
#            D       1.00      0.75      0.86         4
#            E       1.00      1.00      1.00        12
#            M       1.00      1.00      1.00         5
#            N       0.91      0.91      0.91        53
#            P       0.77      1.00      0.87        10
#            R       1.00      1.00      1.00        13
#            V       0.98      0.90      0.94        52
#            X       0.00      0.00      0.00         1
#
#     accuracy                           0.93       174
#    macro avg       0.85      0.86      0.85       174
# weighted avg       0.94      0.93      0.93       174

# %% [markdown]
# # Custom Test

# %%
sentence = ["kiến_thức","đó","rất", "phức_tạp"]

# %%
cidx  = ["kiến_thức"]
rvals = states[1:]
cols = [vocab_dict[word] for word in cidx]
rows = [rvals.index(tag) for tag in rvals]
pd.DataFrame(B[np.ix_(rows, cols)], index=rvals, columns=cidx)
# Out:
#    kiến_thức
# A   0.000036
# C   0.000041
# D   0.000041
# E   0.000035
# I   0.000044
# M   0.000042
# N   0.004867
# P   0.000038
# R   0.000037
# V   0.000027

# %%
best_probs_sent, best_paths_sent = viterbi_initialize(states, tags, A, B, sentence, vocab_dict)
pd.DataFrame(best_probs_sent,
index = states[1:],
columns = sentence)
# Out:
#    kiến_thức   đó  rất  phức_tạp
# A -14.113300  0.0  0.0       0.0
# C -13.285895  0.0  0.0       0.0
# D -12.607610  0.0  0.0       0.0
# E -13.042740  0.0  0.0       0.0
# I -18.533749  0.0  0.0       0.0
# M -13.273369  0.0  0.0       0.0
# N  -6.127879  0.0  0.0       0.0
# P -11.775378  0.0  0.0       0.0
# R -12.992004  0.0  0.0       0.0
# V -13.698252  0.0  0.0       0.0

# %%
best_probs_sent, best_paths_sent = viterbi_forward(A, B, sentence, best_probs_sent, best_paths_sent, vocab_dict)

# %%
pd.DataFrame(best_probs_sent,
index = states[1:],
columns = sentence)
# Out:
#    kiến_thức         đó        rất   phức_tạp
# A -14.113300 -23.456268 -31.549028 -33.704598
# C -13.285895 -23.317048 -32.507088 -39.272487
# D -12.607610 -23.329419 -34.053264 -43.899979
# E -13.042740 -18.862577 -29.586422 -39.433137
# I -18.533749 -23.261596 -33.985442 -43.832157
# M -13.273369 -23.304521 -33.407863 -43.875082
# N  -6.127879 -16.851724 -27.575569 -38.299415
# P -11.775378 -18.796860 -32.015122 -43.324406
# R -12.992004 -23.426962 -25.526092 -36.906613
# V -13.698252 -23.729404 -30.792973 -36.803867

# %%
pd.DataFrame(best_paths_sent,
index = states[1:],
columns = sentence)
# Out:
#    kiến_thức  đó  rất  phức_tạp
# A          0   6    7         8
# C          0   6    7         8
# D          0   6    6         8
# E          0   6    6         8
# I          0   6    6         8
# M          0   6    7         8
# N          0   6    6         6
# P          0   6    7         0
# R          0   6    7         8
# V          0   6    7         8

# %%
sent_pred = viterbi_backward(best_probs_sent, best_paths_sent, test_words, states)

# %%
sent_pred
# Out:
# ['N', 'P', 'R', 'A']

# %%
for word, tag in zip(sentence,sent_pred):
  print(word + "/" + tag, end=" ")
# Out:
# kiến_thức/N đó/P rất/R phức_tạp/A
